# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/content/Salary Data (1).csv')
df
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
plt.scatter(df['Experience Years'],df['Salary']) # Changed 'Years' to 'YearsExperience'

plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
x=np.array(df['Experience Years']).reshape(-1,1)
y=np.array(df['Salary']).reshape(-1,1)

# %%
plt.scatter(x.mean(), y.mean(), color='red', marker='o', s=100)

plt.scatter(x,y,color='blue',marker='.')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.title('Salary Prediction')

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
x.mean()
# Out:
# 5.1525

# %%
y.mean()
# Out:
# 74743.625

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
m=reg.coef_

# %%
c=reg.intercept_

# %%
(m*x+c).mean()
# Out:
# 74743.625

# %%
reg.predict([[9]])
# Out:
# array([[111385.87032729]])

# %%
df['predicted_y']=reg.predict(x)
df
# Out:
#     Experience Years  Salary    predicted_y
# 0                1.1   39343   36149.031319
# 1                1.2   42774   37101.396369
# 2                1.3   46205   38053.761420
# 3                1.5   37731   39958.491522
# 4                2.0   43525   44720.316775
# 5                2.2   39891   46625.046877
# 6                2.5   48266   49482.142029
# 7                2.9   56642   53291.602232
# 8                3.0   60150   54243.967283
# 9                3.2   54445   56148.697384
# 10               3.2   64445   56148.697384
# 11               3.5   60000   59005.792536
# 12               3.7   57189   60910.522638
# 13               3.8   60200   61862.887689
# 14               3.9   63218   62815.252739
# 15               4.0   55794   63767.617790
# 16               4.0   56957   63767.617790
# 17               4.1   57081   64719.982841
# 18               4.3   59095   66624.712942
# 19               4.5   61111   68529.443044
# ...

# %% [markdown]
# Lost and Cost Function

# %%
df['loss']=df['Salary']-df['predicted_y']
df['loss']
# Out:
# 0      3193.968681
# 1      5672.603631
# 2      8151.238580
# 3     -2227.491522
# 4     -1195.316775
# 5     -6734.046877
# 6     -1216.142029
# 7      3350.397768
# 8      5906.032717
# 9     -1703.697384
# 10     8296.302616
# 11      994.207464
# 12    -3721.522638
# 13    -1662.887689
# 14      402.747261
# 15    -7973.617790
# 16    -6810.617790
# 17    -7638.982841
# 18    -7529.712942
# 19    -7418.443044
# 20    -5934.173145
# 21    -4400.903247
# 22    -8214.633348
# 23     6939.636550
# 24     4146.906449
# 25     -499.553754
# 26    11125.081195
# 27     6280.351093
# 28     2423.255941
# 29     1304.160789
# 30     4982.065637
# 31      392.145231
# 32    10045.050079
# 33     4995.954926
# 34      902.224825
# 35    -5803.870327
# 36      821.304419
# 37    -4465.060632
# 38    -1375.615987
# 39    -3799.346088
# Name: loss, dtype: float64

# %%
plt.plot(x, reg.predict(x),color='red')
plt.scatter(x.mean(), y.mean(), color='red', marker='o', s=100)

plt.scatter(x,y,color='blue',marker='.')

plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.title('Salary Prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
mae=mean_absolute_error(df['Salary'],df['predicted_y'])
mae
# Out:
# 4516.281792544623

# %%
mse=mean_squared_error(df['Salary'],df['predicted_y'])
mse
# Out:
# 28960383.65377621

# %%
reg.score(x,y)
# Out:
# 0.9558814451799361

# %%
r2=r2_score(df['Salary'],df['predicted_y'])
r2
# Out:
# 0.9558814451799361
